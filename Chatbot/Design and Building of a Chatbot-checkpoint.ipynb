# %% [markdown]
# #### Business Problem :
#
# A chatbot realted to banking domain which can support and answer the queries of customers with limited scope
#
#
# #### Scope :
#
# Q&A  : What is the interest rate of the bank
#
# Info retrieval : when is my credit card payment due

# %% [markdown]
# #### Modules
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Need to write questions for Intent classification
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Siamese Network
#
# Since the data is less to train, we are using one shot network
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
