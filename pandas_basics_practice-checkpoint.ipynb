# %% [markdown]
# **Consider the following Python dictionary data and Python list labels:**
#
# data = {'birds': ['Cranes', 'Cranes', 'plovers', 'spoonbills', 'spoonbills', 'Cranes', 'plovers', 'Cranes', 'spoonbills', 'spoonbills'],
#         'age': [3.5, 4, 1.5, np.nan, 6, 3, 5.5, np.nan, 8, 4],
#         'visits': [2, 4, 3, 4, 3, 4, 2, 2, 3, 2],
#         'priority': ['yes', 'yes', 'no', 'yes', 'no', 'no', 'no', 'yes', 'no', 'no']}
#
# labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# **1. Create a DataFrame birds from this dictionary data which has the index labels.**

# %%
labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i','j']
Birds = pd.DataFrame(data = {'birds': ['Cranes', 'Cranes', 'plovers', 'spoonbills', 'spoonbills', 'Cranes', 'plovers', 'Cranes', 'spoonbills', 'spoonbills'], 'age': [3.5, 4, 1.5, np.nan, 6, 3, 5.5, np.nan, 8, 4], 'visits': [2, 4, 3, 4, 3, 4, 2, 2, 3, 2], 'priority': ['yes', 'yes', 'no', 'yes', 'no', 'no', 'no', 'yes', 'no', 'no']})


#Birds.index = labels   # need to keep labels at the index 
Birds
# Out:
#         birds  age  visits priority
# 0      Cranes  3.5       2      yes
# 1      Cranes  4.0       4      yes
# 2     plovers  1.5       3       no
# 3  spoonbills  NaN       4      yes
# 4  spoonbills  6.0       3       no
# 5      Cranes  3.0       4       no
# 6     plovers  5.5       2       no
# 7      Cranes  NaN       2      yes
# 8  spoonbills  8.0       3       no
# 9  spoonbills  4.0       2       no

# %% [markdown]
# **2. Display a summary of the basic information about birds DataFrame and its data.**

# %%
print(Birds)
print(Birds.columns)
print(Birds.shape)
# Out:
#         birds  age  visits priority
# 0      Cranes  3.5       2      yes
# 1      Cranes  4.0       4      yes
# 2     plovers  1.5       3       no
# 3  spoonbills  NaN       4      yes
# 4  spoonbills  6.0       3       no
# 5      Cranes  3.0       4       no
# 6     plovers  5.5       2       no
# 7      Cranes  NaN       2      yes
# 8  spoonbills  8.0       3       no
# 9  spoonbills  4.0       2       no
# Index(['birds', 'age', 'visits', 'priority'], dtype='object')
# (10, 4)

# %% [markdown]
# **3. Print the first 2 rows of the birds dataframe**

# %%
#Birds[0:2] # 
Birds.head(2)
# Out:
#     birds  age  visits priority
# 0  Cranes  3.5       2      yes
# 1  Cranes  4.0       4      yes

# %% [markdown]
# **4. Print all the rows with only 'birds' and 'age' columns from the dataframe**

# %%
#Birds[['birds','age']]


Birds.loc[:,['birds','age']]
# Out:
#         birds  age
# 0      Cranes  3.5
# 1      Cranes  4.0
# 2     plovers  1.5
# 3  spoonbills  NaN
# 4  spoonbills  6.0
# 5      Cranes  3.0
# 6     plovers  5.5
# 7      Cranes  NaN
# 8  spoonbills  8.0
# 9  spoonbills  4.0

# %% [markdown]
# **5. select [2, 3, 7] rows and in columns ['birds', 'age', 'visits']**

# %%
b = Birds.iloc[[2,3,7]]
b[['birds', 'age', 'visits']]
#b.loc[:,['birds', 'age', 'visits']]
# Out:
#         birds  age  visits
# 2     plovers  1.5       3
# 3  spoonbills  NaN       4
# 7      Cranes  NaN       2

# %% [markdown]
# **6. select the rows where the number of visits is less than 4**

# %%
#Birds[['birds','age','priority']][Birds['visits'] < 4] 
#Birds.loc[Birds['visits'] < 4]
Birds.loc[:,['birds','age','priority']][Birds['visits'] < 4]
# Out:
#         birds  age priority
# 0      Cranes  3.5      yes
# 2     plovers  1.5       no
# 4  spoonbills  6.0       no
# 6     plovers  5.5       no
# 7      Cranes  NaN      yes
# 8  spoonbills  8.0       no
# 9  spoonbills  4.0       no

# %% [markdown]
# **7. select the rows with columns ['birds', 'visits'] where the age is missing i.e NaN**

# %%
Birds[['birds','visits']][Birds['age'].isnull()]
#Birds.loc[:,['birds','visits']][Birds['age'].isnull()]
# Out:
#         birds  visits
# 3  spoonbills       4
# 7      Cranes       2

# %% [markdown]
# **8. Select the rows where the birds is a Cranes and the age is less than 4**

# %%
Birds[(Birds['birds'] == 'Cranes') & (Birds['age'] < 4) ]
# Out:
#     birds  age  visits priority
# 0  Cranes  3.5       2      yes
# 5  Cranes  3.0       4       no

# %%
#Birds[Birds['age'] < 4][Birds['birds'] =='Cranes' ]

#Birds[Birds['birds'] == 'Cranes'] [Birds['age'] < 4]

Birds[(Birds['birds'] == 'Cranes') & (Birds['age'] < 4)]
# Out:
#     birds  age  visits priority
# 0  Cranes  3.5       2      yes
# 5  Cranes  3.0       4       no

# %% [markdown]
# **9. Select the rows the age is between 2 and 4(inclusive)**

# %%
Birds[(Birds['age'] > 2) & (Birds['age'] <= 4)]
# Out:
#         birds  age  visits priority
# 0      Cranes  3.5       2      yes
# 1      Cranes  4.0       4      yes
# 5      Cranes  3.0       4       no
# 9  spoonbills  4.0       2       no

# %% [markdown]
# **10. Find the total number of visits of the bird Cranes**

# %%
c = Birds[Birds['birds']=='Cranes']
c['visits'].sum()
# Out:
# 12

# %% [markdown]
# **11. Calculate the mean age for each different birds in dataframe.**

# %%
g = Birds.groupby('birds')
print(g)
for birds,birds_df in g:
    #print(birds)
    #print(birds_df)
    print('Mean of age for {} is {}'.format(birds,birds_df['age'].mean()))
# Out:
# ...
# Mean of age for Cranes is 3.5
# Mean of age for plovers is 3.5
# Mean of age for spoonbills is 6.0

# %% [markdown]
# **12. Append a new row 'k' to dataframe with your choice of values for each column. Then delete that row to return the original DataFrame.**

# %%
data = [{'birds':'Khukhaboora','age':2,'visits':4,'priority':'yes'}]
df = pd.DataFrame(data,index = ['k'])
df
#df = pd.DataFrame(data) # can be done as in the beginning
#df.index = ['k']
new = pd.concat([Birds,df],axis=0)
new

Birds = new.drop(['k'])
Birds
# Out:
#         birds  age  visits priority
# 0      Cranes  3.5       2      yes
# 1      Cranes  4.0       4      yes
# 2     plovers  1.5       3       no
# 3  spoonbills  NaN       4      yes
# 4  spoonbills  6.0       3       no
# 5      Cranes  3.0       4       no
# 6     plovers  5.5       2       no
# 7      Cranes  NaN       2      yes
# 8  spoonbills  8.0       3       no
# 9  spoonbills  4.0       2       no

# %% [markdown]
# **13. Find the number of each type of birds in dataframe (Counts)**

# %%
Birds['birds'].value_counts()
# Out:
# spoonbills    4
# Cranes        4
# plovers       2
# Name: birds, dtype: int64

# %% [markdown]
# **14. Sort dataframe (birds) first by the values in the 'age' in decending order, then by the value in the 'visits' column in ascending order.**

# %%
print(Birds)
print('***********')
desc_age = Birds.sort_values('age',ascending=False)
print(desc_age)
print('***********')
asc_visits = desc_age.sort_values('visits',ascending = True)
print(asc_visits)
# Out:
#         birds  age  visits priority
# 0      Cranes  3.5       2      yes
# 1      Cranes  4.0       4      yes
# 2     plovers  1.5       3       no
# 3  spoonbills  NaN       4      yes
# 4  spoonbills  6.0       3       no
# 5      Cranes  3.0       4       no
# 6     plovers  5.5       2       no
# 7      Cranes  NaN       2      yes
# 8  spoonbills  8.0       3       no
# 9  spoonbills  4.0       2       no
# ***********
#         birds  age  visits priority
# 8  spoonbills  8.0       3       no
# 4  spoonbills  6.0       3       no
# 6     plovers  5.5       2       no
# 1      Cranes  4.0       4      yes
# 9  spoonbills  4.0       2       no
# 0      Cranes  3.5       2      yes
# 5      Cranes  3.0       4       no
# 2     plovers  1.5       3       no
# 3  spoonbills  NaN       4      yes
# 7      Cranes  NaN       2      yes
# ***********
#         birds  age  visits priority
# 6     plovers  5.5       2       no
# 9  spoonbills  4.0       2       no
# ...

# %% [markdown]
# **15. Replace the priority column values with'yes' should be 1 and 'no' should be 0**

# %%
Bin_priority = Birds['priority'].replace({'yes':1,'no':0})
Bin_priority
# Out:
# 0    1
# 1    1
# 2    0
# 3    1
# 4    0
# 5    0
# 6    0
# 7    1
# 8    0
# 9    0
# Name: priority, dtype: int64

# %% [markdown]
# **16. In the 'birds' column, change the 'Cranes' entries to 'trumpeters'.**

# %%
Birds['birds'].replace('Cranes','trumpeters')
# Out:
# 0    trumpeters
# 1    trumpeters
# 2       plovers
# 3    spoonbills
# 4    spoonbills
# 5    trumpeters
# 6       plovers
# 7    trumpeters
# 8    spoonbills
# 9    spoonbills
# Name: birds, dtype: object

# %%
#Birds = Birds['age'].fillna(0)
#print(Birds)

# %%
Birds = Birds['age'].replace(np.nan, 0)
print(Birds)
# Out:
# 0    3.5
# 1    4.0
# 2    1.5
# 3    0.0
# 4    6.0
# 5    3.0
# 6    5.5
# 7    0.0
# 8    8.0
# 9    4.0
# Name: age, dtype: float64
